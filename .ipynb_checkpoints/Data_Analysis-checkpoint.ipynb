# %%
import pandas as pd
import random, os
from math import log, pow
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 10})
import numpy as np
from scipy import stats
import antibody_functions as AF
# Out:
# Importing modules from antibody_functions...
# Initializing Rosetta with sugar flags

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
# fill in appropriate filenames and paths here

path_to_native_3ay4 = "/Users/Research/antibody_project/structures/structs_from_louis/3ay4_Fc_FcgRIIIa/automated_mutational_analysis/March_9_2016/native_crystal_struct_3ay4_Fc_FcgRIII.pdb"
path_to_lowest_E_single_pack_min_native_3ay4 = "/Users/Research/antibody_project/structures/structs_from_louis/3ay4_Fc_FcgRIIIa/automated_mutational_analysis/March_9_2016/all_lowest_E_structs/native_crystal_struct_3ay4_Fc_FcgRIII_691.pdb"


# for use in making the RMSD plots and contact map below
#lowest_E_muts_3ay4_dir = "/Users/Research/pyrosetta_git_repo/testing_mut_structs/best_structs/"

# %%
# dictionary of each mutation and its corresponding binding affinity ratio
# RE: Shields, et al. 2001
binding_affinity_dict = { "lowest_E_single_pack_and_min_only_native_crystal_struct_3ay4_Fc_FcgRIII": 1, "S298A_T256A": 1.41, "S298A_E333A_K334A": 1.51, "D265N": 0.02, "S267T": 0.05, "E233P":0.04, "P238A":0.07, "D265A":0.09, "A327Q":0.06, "P329A":0.21, "D270A":0.14, "Q295A":0.25, "A327S":0.06, "T256A":1.32, "K290A":1.31, "R255A":0.98, "E258A":1.12, "S267A":1.05, "E272A":0.8, "N276A":0.95, "D280A":1.09, "H285A":0.87, "N286A":1.05, "T307A":1.09, "L309A":1.07, "N315A":1.07, "K326A":1.23, "P331A":1.08, "S337A":0.94, "A378Q":1.19, "E430A":1.2, "H268A":0.54, "R301A":0.22, "K322A":0.62, "R292A":0.89, "K414A":0.82, "S298A":1.34, "S239A":0.26, "E269A":0.45, "E293A":0.31, "Y296G":0.55, "V303A":0.33, "A327G":0.36, "K338A":0.15, "D376A":0.55, "E333A":1.27, "K334A":1.39, "A339T":1.34 }

# %% [markdown]
# ## do I need this?
# ##### collect the full path names of all of the mutant structures that were manually moved into the low E directory
# low_E_muts_3ay4 = []
# for f in os.listdir( low_E_muts_3ay4_dir ):
#     if f.endswith( ".pdb" ):
#         low_E_muts_3ay4.append( low_E_muts_3ay4_dir + f )

# %% [markdown]
# # Mutational data for glycosylated 3ay4 and its mutations
# ### Just one round of packing and minimization to get low E structures

# %%
#path_to_native_vs_single_pack_min_data = "/Users/Research/antibody_project/structures/structs_from_louis/3ay4_Fc_FcgRIIIa/automated_mutational_analysis/March_9_2016/March_9_analysis_data.csv"
path_to_low_E_pack_min_vs_muts_data = "/Users/Research/pyrosetta_dir/March_9_data.csv"
low_E_vs_muts = pd.read_csv( path_to_low_E_pack_min_vs_muts_data )
low_E_vs_muts = low_E_vs_muts.sort( "Pose Score" )
low_E_vs_muts
# Out:
#                                         Mutation Made  Pose Score  dG Scores  \
# 6                                       D270A_324.pdb -914.501648  -2.321362
# 17                                      H268A_526.pdb -913.991089  -1.810803
# 34                                      R292A_319.pdb -913.338615  -1.158329
# 2                                       A327S_662.pdb -913.272786  -1.092500
# 44                                      Y296A_944.pdb -913.172393  -0.992107
# 3                                       A339T_295.pdb -913.116085  -0.935800
# 4                                         A378Q_2.pdb -913.102664  -0.922378
# 1                                       A327Q_526.pdb -913.041858  -0.861572
# 47                                      Y296W_658.pdb -912.410351  -0.230065
# 26                                      N276A_141.pdb -912.350410  -0.170124
# 9                                       E233P_404.pdb -912.344110  -0.163824
# 28                                      N315A_677.pdb -912.089550   0.090736
# 45                                      Y296F_199.pdb -912.017602   0.162684
# 46                                      Y296K_347.pdb -912.015618   0.164668
# 10                                      E258A_658.pdb -911.972663   0.207623
# 39                                      S298A_341.pdb -911.829503   0.350783
# 8                                       D376A_690.pdb -911.754454   0.425832
# 18                                      H285A_426.pdb -911.744909   0.435377
# 11                                      E269A_978.pdb -911.725162   0.455124
# 36                                      S239A_853.pdb -911.657127   0.523159
# 25                                      L309A_727.pdb -911.620979   0.559307
# 40                                      S337A_192.pdb -911.613566   0.566720
# 21                                      K326A_989.pdb -911.519424   0.660862
# 24                                      K414A_351.pdb -911.269962   0.910324
# 0                                       A327G_117.pdb -911.103791   1.076495
# 19                                      K290A_837.pdb -910.888432   1.291854
# 22                                      K334A_485.pdb -910.614148   1.566138
# 30                                      P329A_460.pdb -910.171987   2.008298
# 12                                      E272A_699.pdb -909.991483   2.188803
# 7                                       D280A_929.pdb -909.904625   2.275661
# 42                                      T307A_951.pdb -909.870582   2.309704
# 27                                      N286A_295.pdb -909.436604   2.743682
# 41                                      T256A_890.pdb -909.427901   2.752385
# 31                                      P331A_323.pdb -909.117122   3.063164
# 20                                      K322A_399.pdb -908.989387   3.190899
# 38                                      S267A_935.pdb -908.913957   3.266329
# 23                                      K338A_701.pdb -908.413828   3.766458
# 35                                      R301A_985.pdb -908.276890   3.903396
# 13                                       E293A_63.pdb -907.946638   4.233648
# 15                                      E430A_221.pdb -907.778365   4.401921
# 33                                      R255A_316.pdb -907.697478   4.482808
# 5                                       D265A_523.pdb -907.561208   4.619078
# 43                                      V303A_707.pdb -907.401703   4.778583
# 32                                      Q295A_726.pdb -907.337249   4.843037
# 14                                      E333A_880.pdb -906.514819   5.665467
# 29                                      P238A_764.pdb -906.087116   6.093170
# 16                          G236A_S239D_I332E_202.pdb -904.089582   8.090704
# 48  Y349C_A+T366W_A+D356C_B+T366S_B+L368A_B+Y407V_... -902.054145  10.126141
# 37                          S239D_A330L_I332E_165.pdb -901.969591  10.210695
# 49  Y349C_A+T366W_A+L234Y_A+L235Y_A+G236W_A+S239M_... -899.590143  12.590143
#
#     Elec Score  dG Elec Scores  Interface Score  dG Interface  Num Hbonds  \
# 6  -248.472332        0.921360       -35.742569     -0.029560         463
# 17 -249.629830       -0.236138       -35.697715      0.015294         463
# 34 -248.992285        0.401407       -35.715890     -0.002881         463
# 2  -251.158227       -1.764535       -35.539860      0.173149         465
# 44 -249.420884       -0.027192       -33.309271      2.403738         463
# 3  -249.770884       -0.377191       -35.724827     -0.011818         463
# 4  -250.698541       -1.304849       -35.715268     -0.002259         463
# 1  -251.768387       -2.374695       -35.200819      0.512190         462
# 47 -249.517230       -0.123537       -36.009146     -0.296137         464
# 30             -3.553645  0.121917
# 12              5.766358  0.002406
# 7              13.553374  0.031707
# 42              1.168587  0.002855
# 27              5.254015  0.002264
# 41              5.158208  0.002756
# 31              6.278702  0.002287
# 20              0.516850  0.006003
# 38              8.531852  0.003226
# 23              3.439648  0.003317
# 35             -4.848509  0.002356
# 13            -14.542448  0.004040
# 15              3.343841  0.003128
# 33              4.673588  0.001844
# 5              -0.831304  0.009068
# 43              0.000000  0.002174
# 32              9.020451  0.003096
# 14              2.432601  0.004035
# 29              7.901912  0.015607
# 16            -45.510864  0.273353
# 48             16.220314  0.172000
# 37             49.159665  0.004823
# 49             44.696432  0.586958

# %%
# RMSD vs Score
rmsd_list = low_E_vs_muts["rmsd"]
score_list = low_E_vs_muts["dG Scores"]

plot_title = "RMSD vs Score - native 3ay4 vs 1000 single pack_min structs.png"

# make scatter plot
plt.scatter( rmsd_list, score_list )
plt.xlabel( "RMSD in Angstroms" )
plt.ylabel( "dREU to Native" )
plt.title( "RMSD vs dREU for glycosylated 3ay4 Shields 2001 Mutations")
#plt.savefig( plot_title, dpi=120, transparent=True )
plt.show()

# %%
colors = [ 'b', 'g', 'c', 'm', 'k' ]

# constants
R = 1.987204118 * pow( 10, -3 )  # kcal K-1 mol-1
T = 293  # 25 degrees Celsius
dG_list = []
RTlnK2K1_list = []

# prepare the figure
plt.figure( 1, figsize=(7,5) )
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)


for index in low_E_vs_muts.index:
    mutation_pdb_name = low_E_vs_muts["Mutation Made"][index]
    mutation_name = mutation_pdb_name.split( '_' )[0]
    
    dG = low_E_vs_muts["dG Interface"][index]
    
    if mutation_name in binding_affinity_dict:
        Ka = binding_affinity_dict[ mutation_name ]
    else:
        Ka = None
    
    if Ka != None:
        dG_list.append( dG )
        RTlnK2K1 = -1 * R * T * log( Ka )
        RTlnK2K1_list.append( RTlnK2K1 )
        
#        uncomment the below line if you want to see the values side-by-side
##        print mutation_name, "    Rosetta:", dG, "    Experimental:", RTlnK2K1
        
        plt.plot( RTlnK2K1, dG, 'o', color="blue", markersize=8 )

        
x_min = min(RTlnK2K1_list)
x_max = max(RTlnK2K1_list)
y_min = min(dG_list)
y_max = max(dG_list)

if x_min < y_min:
    ax_min = int(x_min) - 1
else:
    ax_min = int(y_min) - 1
if x_max > y_max:
    ax_max = int(x_max) + 1
else:
    ax_max = int(y_max) + 1
plt.plot( range( ax_min, ax_max + 1 ), range( ax_min, ax_max + 1 ), color='k')  # one-by-one line

x = np.array( RTlnK2K1_list )
y = np.array( dG_list )

slope, intercept, r_value, p_value, std_err = stats.linregress( x, y )
R_squared = r_value**2
print "R squared value:", R_squared

plt.xlim( ax_min, ax_max )
plt.ylim( ax_min, ax_max )
plt.xlabel( "Experimental -RT * ln( K2/K1 )" )
plt.ylabel( "Rosetta dG Interface" )
plt.title( "Mutations to PDB Glycosylated 3AY4 -- Comparing Experimental to Rosetta" )
#plt.savefig( "Mutations to PDB 3AY4 -- Comparing Experimental to Rosetta", dpi=120, transparent=True )
plt.show()
# Out:
# R squared value: 0.134799985265
